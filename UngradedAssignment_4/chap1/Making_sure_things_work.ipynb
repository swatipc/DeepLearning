# %%
import torch
device = torch.device("cuda:0")

# %%
torch.version.__version__
# Out:
# '1.5.0+cu101'

# %%
a = torch.ones(4,4)

# %%
b = torch.ones(4,4)

# %%
a + b
# Out:
# tensor([[2., 2., 2., 2.],
#         [2., 2., 2., 2.],
#         [2., 2., 2., 2.],
#         [2., 2., 2., 2.]])

# %%
a = a.to('cuda')
b = b.to('cuda')
a + b
# Out:
# tensor([[2., 2., 2., 2.],
#         [2., 2., 2., 2.],
#         [2., 2., 2., 2.],
#         [2., 2., 2., 2.]], device='cuda:0')
